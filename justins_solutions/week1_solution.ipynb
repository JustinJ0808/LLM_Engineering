# %%
# import the required libraries
from dotenv import load_dotenv
from IPython.display import Markdown, display, update_display
from openai import OpenAI
import gradio as gr

# %%
# constants
MODEL = "gpt-4o-mini"

# %%
# set up the OpenAI client
load_dotenv(override=True)
openai = OpenAI()

# Make sure you have your API key set up
if not openai.api_key:
    raise ValueError("OpenAI API key not found")
else:
    print("API key found")
# Out:
# API key found

# %%
# Ask a question to the LLM
question = "explain what is a large language model"

# %%
system_prompt = "You are a helpful assistant."
user_prompt = question

# %%
messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": user_prompt}
]

# %%
stream = openai.chat.completions.create(
    model=MODEL,
    messages=messages,
    stream=True
)
response = ""
display_handle = display(Markdown(""), display_id=True)
for chunck in stream:
    response += chunck.choices[0].delta.content or ""
    update_display(Markdown(response), display_id=display_handle.display_id)
# Out:
# A large language model (LLM) is an artificial intelligence system designed to understand and generate human-like text based on the input it receives. These models are primarily built using deep learning techniques, particularly neural networks, and are trained on vast amounts of text data from diverse sources such as books, websites, and articles.
#
# Here are some key characteristics of large language models:
#
# 1. **Scale**: LLMs are characterized by their size, typically having billions or even trillions of parameters. The "large" in LLM refers not just to their parameter count, but also to the volume of data they are trained on. This scale allows them to capture complex patterns and nuances in language.
#
# 2. **Architecture**: Most large language models are based on transformer architecture, which was introduced in the paper "Attention is All You Need" by Vaswani et al. in 2017. This architecture allows the model to focus on different parts of the input text when making predictions or generating text.
#
# 3. **Training**: LLMs are trained using unsupervised or semi-supervised learning methods. They learn to predict the next word in a sentence given the context provided by previous words (a task known as language modeling). This training process enables them to develop a statistical understanding of language.
#
# 4. **Generative Capability**: LLMs can generate coherent and contextually relevant text, making them useful for a variety of applications, including chatbots, content creation, translation, and more.
#
# 5. **Fine-tuning**: After the initial training, LLMs can be fine-tuned on specific datasets to improve their performance in particular domains or tasks, such as medical terminology or legal language.
#
# 6. **Limitations**: Despite their capabilities, LLMs have limitations. They do not possess true understanding or reasoning abilities. Their responses can sometimes be factually incorrect or biased, reflecting the data they were trained on. They also lack awareness of real-world events after their training cut-off.
#
# Overall, large language models represent a significant advancement in natural language processing and have many practical applications across various fields.
